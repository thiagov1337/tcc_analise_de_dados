# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# !pip install nltk
nltk.download('vader_lexicon')

# Criando uma instância do SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Dados de exemplo: dicionário de filmes e suas respectivas frases
filmes = {
    "Filme A": [
        "I loved this movie! It was amazing.",
        "The end of the film was surprising."
    ],
    "Filme B": [
        "This movie is really bad. I didn't like it.",
        "The acting of the actors left something to be desired."
    ],
    "Filme C": [
        "I didn't understand anything about this movie. It was too confusing."
    ]
}

# Analisando o sentimento por filme
for filme, frases in filmes.items():
    print("Filme:", filme)
    print("Frases:")
    for frase in frases:
        sentiment = sia.polarity_scores(frase)
        print(frase)
        print("Sentimento:", sentiment['compound'])
        print("------------------------")
    print("==============================")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Filme: Filme A
# Frases:
# I loved this movie! It was amazing.
# Sentimento: 0.8398
# ---
# The end of the film was surprising.
# Sentimento: 0.2732
# ---
# ...
# Filme: Filme B
# Frases:
# This movie is really bad. I didn't like it.
# Sentimento: -0.7325
# ---
# The acting of the actors left something to be desired.
# Sentimento: 0.2732
# ---
# ...
# Filme: Filme C
# Frases:
# I didn't understand anything about this movie. It was too confusing.
# Sentimento: -0.2263
# ---
# ...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
